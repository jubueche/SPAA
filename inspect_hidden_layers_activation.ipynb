# %% [markdown]
# # Problem
#
# The attack success-rate of label #7 class has a gap between on-chip testing and simulation testing.
#
# ### e.g. from the statistics that I collectecd
#
# |epoch|target label|patch size|MAX|lambda|success rate(on-chip)|success rate(simulation)|
# |---- |----        |----     |----|----  |----                 |----                    |
# |9|8|0.025|50|5e-4|68.29%|78.05%|
# |9|7|0.025|50|5e-4|**13.89%**|**58.33%**|
# |9|6|0.025|50|5e-4|44.74%|68.42%|
# |9|5|0.025|50|5e-4|58.52%|64.71%|

# %% [markdown]
# We suspect that this is caused by the asynchronus convolution when running on-chip testing. So here we tried to inspect the difference of the numbers of spikes generated by the hidden layers.

# %%
from networks import GestureClassifierSmall
from sinabs.backend.dynapcnn import DynapcnnCompatibleNetwork
from sinabs.layers import SpikingLayer
from tqdm import tqdm
from aermanager.preprocess import create_raster_from_xytp

import os
import torch
import h5py
import numpy as np
# Out:
# finished bindings

# %% [markdown]
# ### Define some global variables we need

# %%
OUTPUTS_OF_SPIKING_LAYERS = []
DEVICE = "cpu"

# %% [markdown]
# ### Define the reset state function and hook function

# %%
def reset_states(net):
    for m in net.modules():
        if hasattr(m, "reset_states"):
            m.reset_states()


def hook_function(module, input_ts, output_ts):
    """forward hook function for nn.Modules that could save the sum of the outputs of hidden layers"""
    OUTPUTS_OF_SPIKING_LAYERS.append(output_ts.sum().item())

# %%
# load weights and convert to quantized snn
gesture_classifier = GestureClassifierSmall("BPTT_small_trained_200ms_2ms.pth", device=DEVICE)
gesture_classifier = gesture_classifier.to(DEVICE)
snn = gesture_classifier.model
quantized_model = DynapcnnCompatibleNetwork(
    snn,
    discretize=True,
    input_shape=(2, 128, 128),
)

# %%
# get spiking layers of the quantized model, we need to register forward hook functions on for them
spiking_layers = [each for each in quantized_model.sequence.modules() if isinstance(each, SpikingLayer)]

# register forward hook functions
for lyr in spiking_layers:
    lyr.register_forward_hook(hook_function)

# %%
# loading the input data from h5 files
# by changing the TARGET_LABEL and N_EPOCH, you can read different attack patches.
N_EPOCH = 9
TARGET_LABEL = 8
MAX = 50
PATCH_SIZE = 0.025

attack_file_name = f"attacks_patches_ep{N_EPOCH}_lb{TARGET_LABEL}_num{MAX}_patchsize{str(PATCH_SIZE).split('.')[1]}.h5"
attack_file = os.path.join("./attack_patches", attack_file_name)
# read data from file
data = h5py.File(attack_file, "r")
successful_attacks = np.where(data["attack_successful"])[0]

# %%
# start to inspect the activation of the hidden layers
for idx in successful_attacks:
    print("=" * 50)
    origin_spk = data["original_spiketrains"][str(idx)]
    attacked_spk = data["attacked_spiketrains"][str(idx)]
    ground_truth = data["ground_truth"][idx]
    assert ground_truth == data["sinabs_label"][idx]
    print(f"Target: {TARGET_LABEL}, ground truth: {ground_truth}")
    
    reset_states(quantized_model.sequence)
    raster_attacked = create_raster_from_xytp(attacked_spk, dt=500, bins_x=np.arange(129), bins_y=np.arange(129))
    output_ts = quantized_model(torch.tensor(raster_attacked).to(DEVICE)).squeeze().sum(0)
    print(f"N. spikes outputs by last layer: {output_ts.sum()}, activations for attacked output: {output_ts.detach().numpy().astype(int)}")
    print(f"N. spikes outputs by hidden layer from attacked input: {OUTPUTS_OF_SPIKING_LAYERS}")
    OUTPUTS_OF_SPIKING_LAYERS.clear()
# Out:
# ==================================================
# Target: 8, ground truth: 7
# N. spikes outputs by last layer: 97.0, activations for attacked output: [12  0  4  8  0  8 15  4 22 15  9]
# N. spikes outputs by hidden layer from attacked input: [45924.0, 26803.0, 2934.0, 97.0]
# ==================================================
# Target: 8, ground truth: 7
# N. spikes outputs by last layer: 69.0, activations for attacked output: [15  0  0  0  0  2  5 18 19  5  5]
# N. spikes outputs by hidden layer from attacked input: [66986.0, 30213.0, 3674.0, 69.0]
# ==================================================
# Target: 8, ground truth: 5
# N. spikes outputs by last layer: 101.0, activations for attacked output: [24  0 11  0  1  7 12  1 26  7 12]
# N. spikes outputs by hidden layer from attacked input: [64344.0, 36406.0, 3941.0, 101.0]
# ==================================================
# Target: 8, ground truth: 3
# N. spikes outputs by last layer: 147.0, activations for attacked output: [22  1  1 23 16 10 10  3 32 13 16]
# N. spikes outputs by hidden layer from attacked input: [54193.0, 36134.0, 3243.0, 147.0]
# ==================================================
# Target: 8, ground truth: 0
# N. spikes outputs by last layer: 132.0, activations for attacked output: [19  0  7 18  9  1  7  0 41 17 13]
# N. spikes outputs by hidden layer from attacked input: [31967.0, 23167.0, 2574.0, 132.0]
# ==================================================
# Target: 8, ground truth: 10
# N. spikes outputs by last layer: 132.0, activations for attacked output: [24  0  0 15  3  1  7  4 40 18 20]
# N. spikes outputs by hidden layer from attacked input: [60400.0, 38887.0, 4028.0, 132.0]
# ==================================================
# Target: 8, ground truth: 9
# N. spikes outputs by last layer: 144.0, activations for attacked output: [ 8  0  8 19  2  1  8 17 35 28 18]
# N. spikes outputs by hidden layer from attacked input: [61854.0, 34020.0, 3298.0, 144.0]
# ==================================================
# Target: 8, ground truth: 5
# N. spikes outputs by last layer: 119.0, activations for attacked output: [14  0  6  4  4 31  9  6 19 16 10]
# N. spikes outputs by hidden layer from attacked input: [80361.0, 43714.0, 4678.0, 119.0]
# ==================================================
# Target: 8, ground truth: 3
# N. spikes outputs by last layer: 207.0, activations for attacked output: [25 20 12 41 12  8 13  5 28 21 22]
# N. spikes outputs by hidden layer from attacked input: [50740.0, 34430.0, 3447.0, 207.0]
# ==================================================
# Target: 8, ground truth: 7
# N. spikes outputs by last layer: 87.0, activations for attacked output: [ 4  0  0  0 10  5  6 20 15 17 10]
# N. spikes outputs by hidden layer from attacked input: [70334.0, 32989.0, 3478.0, 87.0]
# ==================================================
# Target: 8, ground truth: 2
# N. spikes outputs by last layer: 65.0, activations for attacked output: [17  0  0  2  2  4  5  0 25  3  7]
# N. spikes outputs by hidden layer from attacked input: [41800.0, 30544.0, 3558.0, 65.0]
# ==================================================
# Target: 8, ground truth: 3
# N. spikes outputs by last layer: 127.0, activations for attacked output: [22  0  0 14  4  2  8  4 33 21 19]
# N. spikes outputs by hidden layer from attacked input: [48731.0, 31109.0, 2876.0, 127.0]
# ==================================================
# Target: 8, ground truth: 5
# N. spikes outputs by last layer: 118.0, activations for attacked output: [19  0  1  9  0  7 11  4 32 24 11]
# N. spikes outputs by hidden layer from attacked input: [42459.0, 29368.0, 2763.0, 118.0]
# ==================================================
# Target: 8, ground truth: 0
# N. spikes outputs by last layer: 92.0, activations for attacked output: [19  0  0  5  1  5  9  1 30 13  9]
# N. spikes outputs by hidden layer from attacked input: [41652.0, 27304.0, 2485.0, 92.0]
# ==================================================
# Target: 8, ground truth: 9
# N. spikes outputs by last layer: 117.0, activations for attacked output: [19  5  4  7 10  7 12  4 26 15  8]
# N. spikes outputs by hidden layer from attacked input: [37790.0, 25152.0, 2511.0, 117.0]
# ==================================================
# Target: 8, ground truth: 5
# N. spikes outputs by last layer: 81.0, activations for attacked output: [19  0  0  2  0  7  9  3 25  6 10]
# N. spikes outputs by hidden layer from attacked input: [40461.0, 28678.0, 3049.0, 81.0]
# ==================================================
# Target: 8, ground truth: 7
# N. spikes outputs by last layer: 78.0, activations for attacked output: [10  0  0  3  5  3  1  7 28 12  9]
# N. spikes outputs by hidden layer from attacked input: [39280.0, 24766.0, 2791.0, 78.0]
# ==================================================
# Target: 8, ground truth: 6
# N. spikes outputs by last layer: 63.0, activations for attacked output: [12  0  0  1  1  6  9  0 20 10  4]
# N. spikes outputs by hidden layer from attacked input: [47294.0, 28905.0, 2936.0, 63.0]
# ==================================================
# Target: 8, ground truth: 8
# N. spikes outputs by last layer: 86.0, activations for attacked output: [18  0  0  7  0  4  8  3 25 12  9]
# N. spikes outputs by hidden layer from attacked input: [43822.0, 26627.0, 2903.0, 86.0]
# ==================================================
# Target: 8, ground truth: 5
# N. spikes outputs by last layer: 94.0, activations for attacked output: [18  0  3  3  1  8 12  5 25 12  7]
# N. spikes outputs by hidden layer from attacked input: [42420.0, 25616.0, 2597.0, 94.0]
# ==================================================
# Target: 8, ground truth: 10
# N. spikes outputs by last layer: 37.0, activations for attacked output: [ 6  0  0  0  9  0  0  0  1  0 21]
# N. spikes outputs by hidden layer from attacked input: [138473.0, 69077.0, 7560.0, 37.0]
# ==================================================
# Target: 8, ground truth: 9
# N. spikes outputs by last layer: 134.0, activations for attacked output: [21  7  7  5  4  0  8  8 37 20 17]
# N. spikes outputs by hidden layer from attacked input: [42555.0, 29924.0, 2991.0, 134.0]
# ==================================================
# Target: 8, ground truth: 6
# N. spikes outputs by last layer: 99.0, activations for attacked output: [ 8  0  4 11  1  4 14  1 22 19 15]
# N. spikes outputs by hidden layer from attacked input: [42312.0, 28371.0, 3124.0, 99.0]
# ==================================================
# Target: 8, ground truth: 5
# N. spikes outputs by last layer: 67.0, activations for attacked output: [ 6  0  0  5  4  4  2  0 26  9 11]
# N. spikes outputs by hidden layer from attacked input: [39146.0, 27129.0, 2759.0, 67.0]
# ==================================================
# Target: 8, ground truth: 1
# N. spikes outputs by last layer: 112.0, activations for attacked output: [16  2  0 18  2  4  2  4 30 13 21]
# N. spikes outputs by hidden layer from attacked input: [47511.0, 34715.0, 3946.0, 112.0]
# ==================================================
# Target: 8, ground truth: 7
# N. spikes outputs by last layer: 92.0, activations for attacked output: [12  0  0  1  0  3  2 30 24 13  7]
# N. spikes outputs by hidden layer from attacked input: [67525.0, 30600.0, 3934.0, 92.0]
# ==================================================
# Target: 8, ground truth: 10
# N. spikes outputs by last layer: 86.0, activations for attacked output: [16  0 12  0  0  3 11  2 19 11 12]
# N. spikes outputs by hidden layer from attacked input: [60010.0, 34952.0, 3375.0, 86.0]
# ==================================================
# Target: 8, ground truth: 0
# N. spikes outputs by last layer: 91.0, activations for attacked output: [20  0  4  1  0  6 13  4 25 11  7]
# N. spikes outputs by hidden layer from attacked input: [33889.0, 24397.0, 2357.0, 91.0]
# ==================================================
# Target: 8, ground truth: 9
# N. spikes outputs by last layer: 119.0, activations for attacked output: [20  0 12  6  0  3 14  4 24 19 17]
# N. spikes outputs by hidden layer from attacked input: [34704.0, 25758.0, 2814.0, 119.0]
# ==================================================
# Target: 8, ground truth: 4
# N. spikes outputs by last layer: 201.0, activations for attacked output: [ 9  0  2 27 43  0  8  8 30 34 40]
# N. spikes outputs by hidden layer from attacked input: [90477.0, 51003.0, 4322.0, 201.0]
# ==================================================
# Target: 8, ground truth: 5
# N. spikes outputs by last layer: 76.0, activations for attacked output: [10  0  7  0  0  7 13  0 19  8 12]
# N. spikes outputs by hidden layer from attacked input: [47906.0, 33739.0, 3444.0, 76.0]
# ==================================================
# Target: 8, ground truth: 0
# N. spikes outputs by last layer: 52.0, activations for attacked output: [14  1  0  1  3  4  3  0 17  4  5]
# N. spikes outputs by hidden layer from attacked input: [41701.0, 24552.0, 2358.0, 52.0]
# ==================================================
# Target: 8, ground truth: 6
# N. spikes outputs by last layer: 72.0, activations for attacked output: [17  0  0  3  1  2  4  2 25 11  7]
# N. spikes outputs by hidden layer from attacked input: [44584.0, 29778.0, 3293.0, 72.0]
# ==================================================
# Target: 8, ground truth: 3
# N. spikes outputs by last layer: 123.0, activations for attacked output: [22  0 12 21  3  6 12  0 23 13 11]
# N. spikes outputs by hidden layer from attacked input: [64941.0, 41749.0, 3621.0, 123.0]
# ==================================================
# Target: 8, ground truth: 0
# N. spikes outputs by last layer: 98.0, activations for attacked output: [24  0  4  4  2  7 12  3 24 10  8]
# N. spikes outputs by hidden layer from attacked input: [35620.0, 23579.0, 2329.0, 98.0]
# ==================================================
# Target: 8, ground truth: 5
# N. spikes outputs by last layer: 104.0, activations for attacked output: [14  6  0  0  0 29 10  6 19  3 17]
# N. spikes outputs by hidden layer from attacked input: [73795.0, 38333.0, 3196.0, 104.0]
# ==================================================
# Target: 8, ground truth: 9
# N. spikes outputs by last layer: 149.0, activations for attacked output: [17  0  0  3 19  5  5 16 39 28 17]
# N. spikes outputs by hidden layer from attacked input: [43094.0, 28028.0, 2863.0, 149.0]
# ==================================================
# Target: 8, ground truth: 10
# N. spikes outputs by last layer: 96.0, activations for attacked output: [14  0  0  9  2  4  7  6 26 13 15]
# N. spikes outputs by hidden layer from attacked input: [59064.0, 31653.0, 2928.0, 96.0]
# ==================================================
# Target: 8, ground truth: 7
# N. spikes outputs by last layer: 93.0, activations for attacked output: [21  0  1  3  0  7 10  6 28  9  8]
# N. spikes outputs by hidden layer from attacked input: [37186.0, 23840.0, 2370.0, 93.0]
# ==================================================
# Target: 8, ground truth: 6
# N. spikes outputs by last layer: 97.0, activations for attacked output: [14  0  0  8  2  5  5  3 35 16  9]
# N. spikes outputs by hidden layer from attacked input: [52284.0, 32807.0, 3109.0, 97.0]
# ==================================================
# Target: 8, ground truth: 4
# N. spikes outputs by last layer: 166.0, activations for attacked output: [12 11  0 13 43  1  3  2 35 25 21]
# N. spikes outputs by hidden layer from attacked input: [71329.0, 45453.0, 4425.0, 166.0]
# ==================================================
# Target: 8, ground truth: 2
# N. spikes outputs by last layer: 120.0, activations for attacked output: [14  3  8 13 12  9 17  1 23 10 10]
# N. spikes outputs by hidden layer from attacked input: [41487.0, 31410.0, 3387.0, 120.0]
